# %% [markdown]
# # DATASET

# %%
from pymining import itemmining, assocrules, perftesting,seqmining
transactions = open('C:/Users/Sabila/Documents/spark/data/mllib/sample_fpgrowth.txt','r')
list_data=transactions.read().split('\n')
for i in range(0,len(list_data)):
    list_data[i]=list_data[i].split(' ')
list_data
# Out:
# [['r', 'z', 'h', 'k', 'p'],
#  ['z', 'y', 'x', 'w', 'v', 'u', 't', 's'],
#  ['s', 'x', 'o', 'n', 'r'],
#  ['x', 'z', 'y', 'm', 't', 's', 'q', 'e'],
#  ['z'],
#  ['x', 'z', 'y', 'r', 'q', 't', 'p'],
#  ['']]

# %% [markdown]
# # Frequent Item Set

# %%
relim_input = itemmining.get_relim_input(list_data)
report = itemmining.relim(relim_input, min_support=2)
report
# Out:
# {frozenset({'t', 'x', 'y'}): 3,
#  frozenset({'q', 't', 'x', 'y', 'z'}): 2,
#  frozenset({'p'}): 2,
#  frozenset({'z'}): 5,
#  frozenset({'x', 'z'}): 3,
#  frozenset({'q', 'x', 'z'}): 2,
#  frozenset({'s', 'x', 'z'}): 2,
#  frozenset({'s', 't', 'z'}): 2,
#  frozenset({'r'}): 3,
#  frozenset({'p', 'r', 'z'}): 2,
#  frozenset({'t'}): 3,
#  frozenset({'t', 'y'}): 3,
#  frozenset({'t', 'x', 'z'}): 3,
#  frozenset({'s', 't', 'x', 'z'}): 2,
#  frozenset({'s', 't', 'y'}): 2,
#  frozenset({'s', 'x', 'y'}): 2,
#  frozenset({'s', 't', 'x', 'y', 'z'}): 2,
#  frozenset({'q', 'z'}): 2,
#  frozenset({'y', 'z'}): 3,
#  frozenset({'q', 't', 'z'}): 2,
#  frozenset({'y'}): 3,
#  frozenset({'q'}): 2,
#  frozenset({'q', 'x', 'y'}): 2,
#  frozenset({'q', 't', 'x', 'y'}): 2,
#  frozenset({'s', 'y'}): 2,
#  frozenset({'s', 't', 'x', 'y'}): 2,
#  frozenset({'q', 'y'}): 2,
#  frozenset({'s', 'z'}): 2,
#  frozenset({'s', 'x', 'y', 'z'}): 2,
#  frozenset({'q', 't'}): 2,
#  frozenset({'x'}): 4,
#  frozenset({'q', 't', 'x', 'z'}): 2,
#  frozenset({'q', 't', 'y'}): 2,
#  frozenset({'s', 't'}): 2,
#  frozenset({'q', 'x'}): 2,
#  frozenset({'t', 'y', 'z'}): 3,
#  frozenset({'x', 'y'}): 3,
#  frozenset({'x', 'y', 'z'}): 3,
#  frozenset({'r', 'x'}): 2,
#  frozenset({'q', 'y', 'z'}): 2,
#  frozenset({'q', 'x', 'y', 'z'}): 2,
#  frozenset({'s'}): 3,
#  frozenset({'s', 'y', 'z'}): 2,
#  frozenset({'q', 't', 'y', 'z'}): 2,
#  frozenset({'s', 't', 'y', 'z'}): 2,
#  frozenset({'t', 'x'}): 3,
#  frozenset({'s', 'x'}): 3,
#  frozenset({'s', 't', 'x'}): 2,
#  frozenset({'r', 'z'}): 2,
#  frozenset({'t', 'x', 'y', 'z'}): 3,
#  frozenset({'p', 'r'}): 2,
#  frozenset({'t', 'z'}): 3,
#  frozenset({'p', 'z'}): 2,
#  frozenset({'q', 't', 'x'}): 2}

# %% [markdown]
# # Assoc Mining

# %%
relim_input = itemmining.get_relim_input(list_data)
item_sets = itemmining.relim(relim_input, min_support=2)
rules = assocrules.mine_assoc_rules(item_sets, min_support=2, min_confidence=0.5)
rules
# Out:
# [(frozenset({'q', 't', 'x', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q', 'x', 'z'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'q', 'x'}), frozenset({'t', 'y', 'z'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'x', 'y', 'z'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 't', 'y', 'z'}), 2, 0.5),
#  (frozenset({'q', 'z'}), frozenset({'t', 'x', 'y'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'q', 't', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'x'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'q', 't'}), frozenset({'x', 'y', 'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'x', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'q', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'z'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'q', 'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'z'}), frozenset({'q', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x', 'y', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q', 'x', 'y'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'q', 'y'}), frozenset({'t', 'x', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 't', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'q', 't', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'y', 'z'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'y', 'z'}), frozenset({'q', 't', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y', 'z'}), frozenset({'q', 't'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'x', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'q', 't', 'y'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'q', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'y'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'y', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'y', 'z'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'y', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'x', 'y', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'s', 'x', 'y'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'t', 'x', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 't', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'x', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'s', 't', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 't', 'y', 'z'}), 2, 0.5),
#  (frozenset({'s', 'x'}), frozenset({'t', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'y', 'z'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'y', 'z'}), frozenset({'s', 't', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'z'}), frozenset({'t', 'x', 'y'}), 2, 1.0),
#  (frozenset({'x', 'y', 'z'}), frozenset({'s', 't'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'z'}), frozenset({'s', 't', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'x', 'z'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'s', 't', 'x', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'s', 't', 'y'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'s', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'s', 'x', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't'}), frozenset({'x', 'y', 'z'}), 2, 1.0),
#  (frozenset({'t', 'x', 'y'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'s', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'x'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'s', 't', 'y', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'y', 'z'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'z'}), frozenset({'s', 'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'z'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'t', 'x', 'y', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'z'}), frozenset({'s', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'x', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'s', 'x', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'s', 'x'}), frozenset({'t', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 't', 'z'}), 2, 0.5),
#  (frozenset({'s', 'z'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'s', 't'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'x'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'s', 't'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'s', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'x'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q', 'x'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'x', 'y'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 't', 'y'}), 2, 0.5),
#  (frozenset({'q', 't'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'q', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x', 'y'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q', 'y'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 't', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'q', 't'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'y'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'y'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'x', 'y'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 't', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'s', 't'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 't', 'y'}), 2, 0.5),
#  (frozenset({'s', 'x'}), frozenset({'t', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'y'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'s', 'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'t', 'x', 'y'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'s', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'x'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'s', 'x', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'x', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 'y', 'z'}), 2, 0.5),
#  (frozenset({'s', 'x'}), frozenset({'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'y', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'y', 'z'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'z'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'x', 'y', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'z'}), frozenset({'s', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'x', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q', 'x', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q', 'x'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'x', 'z'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 't', 'z'}), 2, 0.5),
#  (frozenset({'q', 'z'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'q', 't'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'x'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'q', 't'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q', 'x'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'x', 'y', 'z'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 'y', 'z'}), 2, 0.5),
#  (frozenset({'q', 'z'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'q', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'q', 'y'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'y', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'y', 'z'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q', 'z'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'y', 'z'}), 2, 1.0),
#  (frozenset({'q', 't'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'z'}), frozenset({'q', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'y', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q', 'y'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 't', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'y', 'z'}), frozenset({'q', 't'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'y', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'y', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 't', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'y', 'z'}), frozenset({'s', 't'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'z'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'s', 't', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'s', 'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'t', 'y', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'z'}), frozenset({'s', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'x', 'y', 'z'}), frozenset({'t'}), 3, 1.0),
#  (frozenset({'x', 'y'}), frozenset({'t', 'z'}), 3, 1.0),
#  (frozenset({'y'}), frozenset({'t', 'x', 'z'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'t', 'y', 'z'}), 3, 0.75),
#  (frozenset({'y', 'z'}), frozenset({'t', 'x'}), 3, 1.0),
#  (frozenset({'z'}), frozenset({'t', 'x', 'y'}), 3, 0.6),
#  (frozenset({'x', 'z'}), frozenset({'t', 'y'}), 3, 1.0),
#  (frozenset({'t', 'x', 'y'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'x', 'z'}), 3, 1.0),
#  (frozenset({'t'}), frozenset({'x', 'y', 'z'}), 3, 1.0),
#  (frozenset({'t', 'x'}), frozenset({'y', 'z'}), 3, 1.0),
#  (frozenset({'t', 'y', 'z'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'x', 'y'}), 3, 1.0),
#  (frozenset({'t', 'x', 'z'}), frozenset({'y'}), 3, 1.0),
#  (frozenset({'x', 'y'}), frozenset({'t'}), 3, 1.0),
#  (frozenset({'y'}), frozenset({'t', 'x'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'t', 'y'}), 3, 0.75),
#  (frozenset({'t', 'y'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'t'}), frozenset({'x', 'y'}), 3, 1.0),
#  (frozenset({'t', 'x'}), frozenset({'y'}), 3, 1.0),
#  (frozenset({'q', 'x'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'x', 'z'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 'z'}), 2, 0.5),
#  (frozenset({'q', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'x'}), frozenset({'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'x', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 'z'}), 2, 0.5),
#  (frozenset({'s', 'z'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'s'}), frozenset({'t', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'r', 'z'}), frozenset({'p'}), 2, 1.0),
#  (frozenset({'r'}), frozenset({'p', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'p', 'z'}), frozenset({'r'}), 2, 1.0),
#  (frozenset({'p'}), frozenset({'r', 'z'}), 2, 1.0),
#  (frozenset({'p', 'r'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'x', 'z'}), frozenset({'t'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'t', 'z'}), 3, 0.75),
#  (frozenset({'z'}), frozenset({'t', 'x'}), 3, 0.6),
#  (frozenset({'t', 'x'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'t'}), frozenset({'x', 'z'}), 3, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'q', 'z'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'z'}), 2, 1.0),
#  (frozenset({'q', 't'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'y'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 't'}), 2, 0.6666666666666666),
#  (frozenset({'q'}), frozenset({'t', 'y'}), 2, 1.0),
#  (frozenset({'t', 'y'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'q', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'q', 't'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 't'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'y'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'s', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'s', 't'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'x', 'y'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 'y'}), 2, 0.5),
#  (frozenset({'s', 'x'}), frozenset({'y'}), 2, 0.6666666666666666),
#  (frozenset({'y', 'z'}), frozenset({'t'}), 3, 1.0),
#  (frozenset({'y'}), frozenset({'t', 'z'}), 3, 1.0),
#  (frozenset({'z'}), frozenset({'t', 'y'}), 3, 0.6),
#  (frozenset({'t', 'y'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'t'}), frozenset({'y', 'z'}), 3, 1.0),
#  (frozenset({'t', 'z'}), frozenset({'y'}), 3, 1.0),
#  (frozenset({'x', 'y'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'y'}), frozenset({'x', 'z'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'y', 'z'}), 3, 0.75),
#  (frozenset({'y', 'z'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'z'}), frozenset({'x', 'y'}), 3, 0.6),
#  (frozenset({'x', 'z'}), frozenset({'y'}), 3, 1.0),
#  (frozenset({'s', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'s', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'y', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'y', 'z'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'s', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'s', 'x'}), frozenset({'t'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'s', 't'}), 2, 0.5),
#  (frozenset({'s', 't'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'s', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'x', 'y'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 'y'}), 2, 0.5),
#  (frozenset({'q', 'y'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'x', 'y'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'z'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'y', 'z'}), 2, 1.0),
#  (frozenset({'q', 'y'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q', 'z'}), 2, 0.6666666666666666),
#  (frozenset({'y', 'z'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q', 'x'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'q'}), frozenset({'t', 'x'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q', 't'}), 2, 0.5),
#  (frozenset({'q', 't'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q', 'x'}), 2, 0.6666666666666666),
#  (frozenset({'t', 'x'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'z'}), 3, 0.75),
#  (frozenset({'z'}), frozenset({'x'}), 3, 0.6),
#  (frozenset({'y'}), frozenset({'t'}), 3, 1.0),
#  (frozenset({'t'}), frozenset({'y'}), 3, 1.0),
#  (frozenset({'q'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'z'}), frozenset({'y'}), 3, 0.6),
#  (frozenset({'y'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'y'}), 2, 0.6666666666666666),
#  (frozenset({'q'}), frozenset({'y'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'t'}), 2, 0.6666666666666666),
#  (frozenset({'t'}), frozenset({'s'}), 2, 0.6666666666666666),
#  (frozenset({'q'}), frozenset({'t'}), 2, 1.0),
#  (frozenset({'t'}), frozenset({'q'}), 2, 0.6666666666666666),
#  (frozenset({'q'}), frozenset({'x'}), 2, 1.0),
#  (frozenset({'x'}), frozenset({'q'}), 2, 0.5),
#  (frozenset({'r'}), frozenset({'x'}), 2, 0.6666666666666666),
#  (frozenset({'x'}), frozenset({'r'}), 2, 0.5),
#  (frozenset({'x'}), frozenset({'t'}), 3, 0.75),
#  (frozenset({'t'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'r'}), frozenset({'z'}), 2, 0.6666666666666666),
#  (frozenset({'s'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'s'}), 3, 0.75),
#  (frozenset({'r'}), frozenset({'p'}), 2, 0.6666666666666666),
#  (frozenset({'p'}), frozenset({'r'}), 2, 1.0),
#  (frozenset({'z'}), frozenset({'t'}), 3, 0.6),
#  (frozenset({'t'}), frozenset({'z'}), 3, 1.0),
#  (frozenset({'p'}), frozenset({'z'}), 2, 1.0),
#  (frozenset({'y'}), frozenset({'x'}), 3, 1.0),
#  (frozenset({'x'}), frozenset({'y'}), 3, 0.75)]

# %% [markdown]
# # Seq Mining

# %%
freq_seqs = seqmining.freq_seq_enum(list_data, 2)
sorted(freq_seqs)
# Out:
# [(('p',), 2),
#  (('q',), 2),
#  (('r',), 3),
#  (('r', 'p'), 2),
#  (('s',), 3),
#  (('t',), 3),
#  (('t', 's'), 2),
#  (('x',), 4),
#  (('x', 'q'), 2),
#  (('x', 'r'), 2),
#  (('x', 's'), 2),
#  (('x', 't'), 3),
#  (('x', 't', 's'), 2),
#  (('x', 'y'), 2),
#  (('x', 'y', 'q'), 2),
#  (('x', 'y', 't'), 2),
#  (('x', 'z'), 2),
#  (('x', 'z', 'q'), 2),
#  (('x', 'z', 't'), 2),
#  (('x', 'z', 'y'), 2),
#  (('x', 'z', 'y', 'q'), 2),
#  (('x', 'z', 'y', 't'), 2),
#  (('y',), 3),
#  (('y', 'q'), 2),
#  (('y', 's'), 2),
#  (('y', 't'), 3),
#  (('y', 't', 's'), 2),
#  (('z',), 5),
#  (('z', 'p'), 2),
#  (('z', 'q'), 2),
#  (('z', 's'), 2),
#  (('z', 't'), 3),
#  (('z', 't', 's'), 2),
#  (('z', 'y'), 3),
#  (('z', 'y', 'q'), 2),
#  (('z', 'y', 's'), 2),
#  (('z', 'y', 't'), 3),
#  (('z', 'y', 't', 's'), 2)]
